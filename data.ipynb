# %%
# Milk sales peak in the morning due to breakfast consumption, lunchboxes, and coffee. They dip mid-morning and lunchtime, 
# then rise slightly in the afternoon for snacks and baking. 
# Late evening sees another small rise for dinners and bedtime drinks, before falling again at night.

# %%
import matplotlib.pyplot as plt
import random
import pandas as pd
import numpy as np

# %% [markdown]
# Sales Data

# %%
# # Define the trend of milk sales throughout the day
# sales_trend = {
#     "morning": {"peak": 0.8, "dip": 0.2},
#     "mid_morning": {"peak": 0.4, "dip": 0.4},
#     "lunchtime": {"peak": 0.2, "dip": 0.6},
#     "afternoon": {"peak": 0.2, "dip": 0.6},
#     "late_evening": {"peak": 0.6, "dip": 0.2},
#     "night": {"peak": 0.2, "dip": 0.5}
#     }

# # Initialize an empty list to store the generated data
# data = []

# # Generate random milk sales data for 100 days
# for day in range(1, 1001):
#     for time_period, probabilities in sales_trend.items():
#         # Determine the peak or dip for this time period
#         is_peak = random.random() < probabilities["peak"]
#         is_dip = random.random() < probabilities["dip"]
        
#         # Generate sales based on the peak or dip probabilities
#         if is_peak and not is_dip:
#             # Peak sales
#             units_sold = random.randint(80, 100)  # Adjust the range of sales as needed
#         elif not is_peak and is_dip:
#             # Dip sales
#             units_sold = random.randint(0, 20)  # Adjust the range of sales as needed
#         else:
#             # Normal sales
#             units_sold = random.randint(30, 50)  # Adjust the range of sales as needed
        
#         # Append the sales data to the list
#         data.append({"Day": f"Day {day}", "Time Period": time_period, "Units Sold": units_sold})

# # Create a DataFrame from the generated data
# sales_df = pd.DataFrame(data)

# # Display the generated DataFrame
# print(sales_df)

# %%
d_trend = {
    "morning": 40,
    "mid_morning": 10,
    "lunchtime": 5,
    "afternoon": 10,
    "late_evening": 25,
    "night": 10
    }

# 100-200 liter per day 
# 45-60 rupees per liter

m_trend = {
    "Winter": {"peak": 0.8, "dip": 0.2},
    "Spring": {"peak": 0.4, "dip": 0.4},
    "Summer": {"peak": 0.2, "dip": 0.6},
    "Fall": {"peak": 0.3, "dip": 0.5},
}

sale=random.randint(100, 200)
print(sale)
# Out:
# 156

# %%
# # Define the trend of milk sales throughout the day
# sales_trend = {
#     "morning": {"peak": 0.8, "dip": 0.2},
#     "mid_morning": {"peak": 0.4, "dip": 0.4},
#     "lunchtime": {"peak": 0.2, "dip": 0.6},
#     "afternoon": {"peak": 0.3, "dip": 0.5},
#     "late_evening": {"peak": 0.6, "dip": 0.2},
#     "night": {"peak": 0.2, "dip": 0.5}
# }

# # Define the seasonal trends
# seasonal_trend = {
#     "Winter": {"morning": 0.7, "mid_morning": 0.3, "lunchtime": 0.1, "afternoon": 0.2, "late_evening": 0.6, "night": 0.2},
#     "Spring": {"morning": 0.4, "mid_morning": 0.5, "lunchtime": 0.3, "afternoon": 0.4, "late_evening": 0.5, "night": 0.3},
#     "Summer": {"morning": 0.2, "mid_morning": 0.3, "lunchtime": 0.4, "afternoon": 0.5, "late_evening": 0.2, "night": 0.4},
#     "Fall": {"morning": 0.5, "mid_morning": 0.4, "lunchtime": 0.3, "afternoon": 0.4, "late_evening": 0.3, "night": 0.3}
# }

# # Initialize an empty list to store the generated data
# data = []

# # Generate random milk sales data for 1000 days
# for day in range(1, 100001):
#     for season in ["Winter", "Spring", "Summer", "Fall"]:
#         for time_period, probabilities in sales_trend.items():
#             # Determine the peak or dip for this time period based on the season
#             is_peak = random.random() < (probabilities["peak"] * seasonal_trend[season][time_period])
#             is_dip = random.random() < (probabilities["dip"] * seasonal_trend[season][time_period])
            
#             # Generate sales based on the peak or dip probabilities
#             if is_peak and not is_dip:
#                 # Peak sales
#                 units_sold = random.randint(80, 100)  # Adjust the range of sales as needed
#             elif not is_peak and is_dip:
#                 # Dip sales
#                 units_sold = random.randint(0, 20)  # Adjust the range of sales as needed
#             else:
#                 # Normal sales
#                 units_sold = random.randint(30, 50)  # Adjust the range of sales as needed
            
#             # Append the sales data to the list
#             data.append({"Day": f"Day {day}", "Time Period": time_period, "Units Sold": units_sold, "Season": season})

# # Create a DataFrame from the generated data
# sales_df = pd.DataFrame(data)

# # Display the generated DataFrame
# print(sales_df)

# %%
# sales_df.groupby('Time Period')['Units Sold'].sum()

# %%
# import random
# import pandas as pd

# # Define the trend of milk sales throughout the day
# throughout_day_trend = {
#     "morning": {"peak": 0.8, "dip": 0.2},
#     "mid_morning": {"peak": 0.4, "dip": 0.4},
#     "lunchtime": {"peak": 0.2, "dip": 0.6},
#     "afternoon": {"peak": 0.3, "dip": 0.5},
#     "late_evening": {"peak": 0.6, "dip": 0.2},
#     "night": {"peak": 0.2, "dip": 0.5}
# }

# # Define the trend of milk sales throughout the year
# # throughout_year_trend = {
# #     "Winter": {"morning": 0.7, "mid_morning": 0.3, "lunchtime": 0.1, "afternoon": 0.2, "late_evening": 0.6, "night": 0.2},
# #     "Spring": {"morning": 0.4, "mid_morning": 0.5, "lunchtime": 0.3, "afternoon": 0.4, "late_evening": 0.5, "night": 0.3},
# #     "Summer": {"morning": 0.2, "mid_morning": 0.3, "lunchtime": 0.4, "afternoon": 0.5, "late_evening": 0.2, "night": 0.4},
# #     "Fall": {"morning": 0.5, "mid_morning": 0.4, "lunchtime": 0.3, "afternoon": 0.4, "late_evening": 0.3, "night": 0.3}
# # }




# throughout_year_trend = {
#     "Winter": {"morning": 0.7, "mid_morning": 0.3, "lunchtime": 0.1, "afternoon": 0.2, "late_evening": 0.6, "night": 0.2},
#     "Spring": {"morning": 0.0, "mid_morning": 0.5, "lunchtime": 0.3, "afternoon": 0.4, "late_evening": 0.5, "night": 0.3},
#     "Summer": {"morning": 0.5, "mid_morning": 0.3, "lunchtime": 0.4, "afternoon": 0.5, "late_evening": 0.2, "night": 0.4},
#     "Fall": {"morning": 0.0, "mid_morning": 0.4, "lunchtime": 0.3, "afternoon": 0.4, "late_evening": 0.3, "night": 0.3}
# }

# # Initialize an empty list to store the generated data
# data = []

# # Generate random milk sales data for 1000 days
# for day in range(1, 1001):
#     for season, season_trend in throughout_year_trend.items():
#         for time_period, throughout_day_probabilities in throughout_day_trend.items():
#             # Get the probabilities for the current time period and season
#             probability_peak = throughout_day_probabilities["peak"] * season_trend[time_period]
#             probability_dip = throughout_day_probabilities["dip"]
            
#             # Determine the peak or dip for this time period and season
#             is_peak = random.random() < probability_peak
#             is_dip = random.random() < probability_dip
            
#             # Generate sales based on the peak or dip probabilities
#             if is_peak and not is_dip:
#                 # Peak sales
#                 units_sold = random.randint(80, 100)  # Adjust the range of sales as needed
#             elif not is_peak and is_dip:
#                 # Dip sales
#                 units_sold = random.randint(0, 20)  # Adjust the range of sales as needed
#             else:
#                 # Normal sales
#                 units_sold = random.randint(30, 50)  # Adjust the range of sales as needed
            
#             # Append the sales data to the list
#             data.append({"Day": f"Day {day}", "Time Period": time_period, "Units Sold": units_sold, "Season": season})

# # Create a DataFrame from the generated data
# sales_df = pd.DataFrame(data)

# # Display the generated DataFrame
# # print(sales_df)

# %%
# import matplotlib.pyplot as plt

# # Create a figure with two subplots
# fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# # Plot the first graph on ax1
# custom_order_time = ["morning", "mid_morning", "lunchtime", "afternoon", "late_evening", "night"]
# sales_time = sales_df.groupby('Time Period')['Units Sold'].sum().loc[custom_order_time]
# sales_time.plot(kind='bar', color='skyblue', label='Bar Chart', ax=ax1)
# sales_time.plot(kind='line', marker='o', color='orange', linewidth=2, label='Frequency Polygon', ax=ax1)
# ax1.set_title('Milk Sales by Time Period')
# ax1.set_xlabel('Time Period')
# ax1.set_ylabel('Units Sold')
# ax1.set_xticklabels(custom_order_time, rotation=45, ha='right')  # Rotate x-axis labels
# ax1.grid(axis='y', linestyle='--', alpha=0.7)
# # ax1.legend()

# # Plot the second graph on ax2
# custom_order_season = ["Summer", "Spring" , "Fall" , "Winter"]
# sales_season = sales_df.groupby('Season')['Units Sold'].sum().loc[custom_order_season]
# sales_season.plot(kind='bar', color='skyblue', label='Bar Chart', ax=ax2)
# sales_season.plot(kind='line', marker='o', color='orange', linewidth=2, label='Frequency Polygonn', ax=ax2)
# ax2.set_title('Milk Sales by Season')
# ax2.set_xlabel('Season')
# # ax2.set_ylabel('Units Sold')
# ax2.set_xticklabels(custom_order_season, rotation=45, ha='right')  # Rotate x-axis labels
# ax2.grid(axis='y', linestyle='--', alpha=0.7)
# # ax2.legend()

# # Adjust spacing between subplots
# plt.tight_layout()

# # Show the combined plot
# plt.show()

# %%
# sales_df.head()

# %%
import random
import pandas as pd

# Define the trend of milk sales throughout the day
sales_trend = {
    "morning": {"peak": 0.8, "dip": 0.2},
    "mid_morning": {"peak": 0.4, "dip": 0.4},
    "lunchtime": {"peak": 0.2, "dip": 0.6},
    "afternoon": {"peak": 0.3, "dip": 0.5},
    "late_evening": {"peak": 0.6, "dip": 0.2},
    "night": {"peak": 0.2, "dip": 0.5}
}

# Define the seasonal trends
throughout_year_trend = {
    "Summer": {"morning": 0.4, "mid_morning": 0.3, "lunchtime": 0.3, "afternoon": 0.2, "late_evening": 0.4, "night": 0.2},
    "Spring": {"morning": 0.2, "mid_morning": 0.2, "lunchtime": 0.2, "afternoon": 0.1, "late_evening": 0.2, "night": 0.2},
    "Fall": {"morning": 0.3, "mid_morning": 0.4, "lunchtime": 0.4, "afternoon": 0.3, "late_evening": 0.3, "night": 0.2},
    "Winter": {"morning": 0.6, "mid_morning": 0.5, "lunchtime": 0.5, "afternoon": 0.4, "late_evening": 0.6, "night": 0.3}
}


seasonal_trend = throughout_year_trend

# Define price range of milk per liter (in rupees)
min_price ,max_price = 45,60
# max_price = 60

# Initialize an empty list to store the generated data
data = []

# Generate random milk sales data for 1000 days
for day in range(1, 1001):
    for season in ["Winter", "Spring", "Summer", "Fall"]:
        # Determine the price of milk based on seasonal demand
        if season in ["Summer", "Winter"]:
            price = random.randint(min_price, max_price - 5)  # Lower price during peak demand seasons
        else:
            price = random.randint(min_price + 5, max_price)  # Higher price during off-peak seasons
        
        for time_period, probabilities in sales_trend.items():
            # Determine the peak or dip for this time period based on the season
            is_peak = random.random() < (probabilities["peak"] * seasonal_trend[season][time_period])
            is_dip = random.random() < (probabilities["dip"] * seasonal_trend[season][time_period])
            
            # Generate sales based on the peak or dip probabilities
            if is_peak and not is_dip:
                # Peak sales
                units_sold = random.randint(80, 100)  # Adjust the range of sales as needed
            elif not is_peak and is_dip:
                # Dip sales
                units_sold = random.randint(0, 20)  # Adjust the range of sales as needed
            else:
                # Normal sales
                units_sold = random.randint(30, 50)  # Adjust the range of sales as needed
            
            # Append the sales data to the list
            data.append({"Day": f"Day {day}", "Time Period": time_period, "Units Sold": units_sold, "Season": season, "Price per Liter": price})

# Create a DataFrame from the generated data
sales_df2 = pd.DataFrame(data)

# Display the generated DataFrame
print(sales_df2)
# Out:
#             Day   Time Period  Units Sold  Season  Price per Liter
# 0         Day 1       morning          85  Winter               45
# 1         Day 1   mid_morning          16  Winter               45
# 2         Day 1     lunchtime          49  Winter               45
# 3         Day 1     afternoon          46  Winter               45
# 4         Day 1  late_evening          91  Winter               45
# ...         ...           ...         ...     ...              ...
# 23995  Day 1000   mid_morning          49    Fall               56
# 23996  Day 1000     lunchtime          38    Fall               56
# 23997  Day 1000     afternoon          36    Fall               56
# 23998  Day 1000  late_evening          40    Fall               56
# 23999  Day 1000         night          46    Fall               56
#
# [24000 rows x 5 columns]

# %%
#order
custom_order_time = ["morning", "mid_morning", "lunchtime", "afternoon", "late_evening", "night"]
custom_order_season = ["Summer", "Spring", "Fall", "Winter"]

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(12, 8))

#graphs for 'Units Sold' on top subplots
ax1.bar(custom_order_time, sales_df2.groupby('Time Period')['Units Sold'].sum().loc[custom_order_time], color='skyblue', label='Bar Chart')
ax1.plot(custom_order_time, sales_df2.groupby('Time Period')['Units Sold'].sum().loc[custom_order_time], marker='o', color='orange', linewidth=2, label='Frequency Polygon')
ax1.set_title('Milk Sales by Time Period')
ax1.set_xlabel('Time Period')
ax1.set_ylabel('Units Sold')
ax1.set_xticklabels(custom_order_time, rotation=45, ha='right')
ax1.grid(axis='y', linestyle='--', alpha=0.7)

ax2.bar(custom_order_season, sales_df2.groupby('Season')['Units Sold'].sum().loc[custom_order_season], color='skyblue', label='Bar Chart')
ax2.plot(custom_order_season, sales_df2.groupby('Season')['Units Sold'].sum().loc[custom_order_season], marker='o', color='orange', linewidth=2, label='Frequency Polygon')
ax2.set_title('Milk Sales by Season')
ax2.set_xlabel('Season')
ax2.set_ylabel('Units Sold')
ax2.set_xticklabels(custom_order_season, rotation=45, ha='right')
ax2.grid(axis='y', linestyle='--', alpha=0.7)

#graphs for 'Price per Liter' on bottom subplots
ax3.bar(custom_order_time, sales_df2.groupby('Time Period')['Price per Liter'].sum().loc[custom_order_time], color='skyblue', label='Bar Chart')
ax3.plot(custom_order_time, sales_df2.groupby('Time Period')['Price per Liter'].sum().loc[custom_order_time], marker='o', color='orange', linewidth=2, label='Frequency Polygon')
ax3.set_title('Milk Rates by Time Period')
ax3.set_xlabel('Time Period')
ax3.set_ylabel('Price per Liter')
ax3.set_xticklabels(custom_order_time, rotation=45, ha='right')
ax3.grid(axis='y', linestyle='--', alpha=0.7)

ax4.bar(custom_order_season, sales_df2.groupby('Season')['Price per Liter'].sum().loc[custom_order_season], color='skyblue', label='Bar Chart')
ax4.plot(custom_order_season, sales_df2.groupby('Season')['Price per Liter'].sum().loc[custom_order_season], marker='o', color='orange', linewidth=2, label='Frequency Polygon')
ax4.set_title('Milk Rates by Season')
ax4.set_xlabel('Season')
ax4.set_ylabel('Price per Liter')
ax4.set_xticklabels(custom_order_season, rotation=45, ha='right')
ax4.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_19168\3451714404.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(custom_order_time, rotation=45, ha='right')
# C:\Users\acer\AppData\Local\Temp\ipykernel_19168\3451714404.py:21: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(custom_order_season, rotation=45, ha='right')
# C:\Users\acer\AppData\Local\Temp\ipykernel_19168\3451714404.py:30: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax3.set_xticklabels(custom_order_time, rotation=45, ha='right')
# C:\Users\acer\AppData\Local\Temp\ipykernel_19168\3451714404.py:38: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax4.set_xticklabels(custom_order_season, rotation=45, ha='right')

# %%
# # Define custom orders and dataframes (assume sales_df2 contains relevant data)
# custom_order_time = ["morning", "mid_morning", "lunchtime", "afternoon", "late_evening", "night"]
# custom_order_season = ["Summer", "Spring", "Fall", "Winter"]

# # Create a figure with 2 rows and 2 columns of subplots
# fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(12, 8))

# # Plot graphs for 'Units Sold' on top subplots
# ax1.bar(custom_order_time, sales_df2.groupby('Time Period')['Units Sold'].sum().loc[custom_order_time], color='skyblue', label='Bar Chart')
# ax1.plot(custom_order_time, sales_df2.groupby('Time Period')['Units Sold'].sum().loc[custom_order_time], marker='o', color='orange', linewidth=2, label='Trend Line')
# ax1.set_title('Milk Sales by Time Period')
# ax1.set_xlabel('Time Period')
# ax1.set_ylabel('Units Sold')
# ax1.set_xticklabels(custom_order_time, rotation=45, ha='right')
# ax1.grid(axis='y', linestyle='--', alpha=0.7)

# ax2.bar(custom_order_season, sales_df2.groupby('Season')['Units Sold'].sum().loc[custom_order_season], color='skyblue', label='Bar Chart')
# ax2.plot(custom_order_season, sales_df2.groupby('Season')['Units Sold'].sum().loc[custom_order_season], marker='o', color='orange', linewidth=2, label='Trend Line')
# ax2.set_title('Milk Sales by Season')
# ax2.set_xlabel('Season')
# ax2.set_ylabel('Units Sold')
# ax2.set_xticklabels(custom_order_season, rotation=45, ha='right')
# ax2.grid(axis='y', linestyle='--', alpha=0.7)

# # Plot graphs for 'Price per Liter' on bottom subplots
# ax3.bar(custom_order_time, sales_df2.groupby('Time Period')['Price per Liter'].sum().loc[custom_order_time], color='skyblue', label='Bar Chart')
# ax3.plot(custom_order_time, sales_df2.groupby('Time Period')['Price per Liter'].sum().loc[custom_order_time], marker='o', color='orange', linewidth=2, label='Trend Line')
# ax3.set_title('Milk Rates by Time Period')
# ax3.set_xlabel('Time Period')
# ax3.set_ylabel('Price per Liter')  # Adjust y-axis label
# ax3.set_xticklabels(custom_order_time, rotation=45, ha='right')
# ax3.grid(axis='y', linestyle='--', alpha=0.7)

# ax4.bar(custom_order_season, sales_df2.groupby('Season')['Price per Liter'].sum().loc[custom_order_season], color='skyblue', label='Bar Chart')
# ax4.plot(custom_order_season, sales_df2.groupby('Season')['Price per Liter'].sum().loc[custom_order_season], marker='o', color='orange', linewidth=2, label='Trend Line')
# ax4.set_title('Milk Rates by Season')
# ax4.set_xlabel('Season')
# ax4.set_ylabel('Price per Liter')  # Adjust y-axis label
# ax4.set_xticklabels(custom_order_season, rotation=45, ha='right')
# ax4.grid(axis='y', linestyle='--', alpha=0.7)

# # Adjust spacing and add a single, optional legend
# plt.tight_layout()
# # Show the combined plot
# plt.show()

# %%
#

# %%
# # Create a figure with two subplots
# fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# # Plot the first graph on ax1
# custom_order_time = ["morning", "mid_morning", "lunchtime", "afternoon", "late_evening", "night"]
# sales_time = sales_df2.groupby('Time Period')['Units Sold'].sum().loc[custom_order_time]
# sales_time.plot(kind='bar', color='skyblue', label='Bar Chart', ax=ax1)
# sales_time.plot(kind='line', marker='o', color='orange', linewidth=2, label='Frequency Polygon', ax=ax1)
# ax1.set_title('Milk Sales by Time Period')
# ax1.set_xlabel('Time Period')
# ax1.set_ylabel('Units Sold')
# ax1.set_xticklabels(custom_order_time, rotation=45, ha='right')  # Rotate x-axis labels
# ax1.grid(axis='y', linestyle='--', alpha=0.7)
# # ax1.legend()

# # Plot the second graph on ax2
# custom_order_season = ["Summer", "Spring" , "Fall" , "Winter"]
# sales_season = sales_df2.groupby('Season')['Units Sold'].sum().loc[custom_order_season]
# sales_season.plot(kind='bar', color='skyblue', label='Bar Chart', ax=ax2)
# sales_season.plot(kind='line', marker='o', color='orange', linewidth=2, label='Frequency Polygonn', ax=ax2)
# ax2.set_title('Milk Sales by Season')
# ax2.set_xlabel('Season')
# # ax2.set_ylabel('Units Sold')
# ax2.set_xticklabels(custom_order_season, rotation=45, ha='right')  # Rotate x-axis labels
# ax2.grid(axis='y', linestyle='--', alpha=0.7)
# # ax2.legend()

# # Adjust spacing between subplots
# plt.tight_layout()

# # Show the combined plot
# plt.show()

# %%
# custom_order = ["morning", "mid_morning", "lunchtime", "afternoon", "late_evening", "night"]
# plt.figure(figsize=(6, 6))

# # Plot the bar chart
# sales_df.groupby('Time Period')['Units Sold'].sum().loc[custom_order].plot(kind='bar', color='skyblue', label='Bar Chart')

# # Plot the frequency polygon
# sales_df.groupby('Time Period')['Units Sold'].sum().loc[custom_order].plot(kind='line', marker='o', color='orange', linewidth=2, label='Frequency Polygon')

# plt.title('Milk Sales by Time Period')
# plt.xlabel('Time Period')
# plt.ylabel('Units Sold')
# plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
# plt.grid(axis='y', linestyle='--', alpha=0.7)
# plt.legend()  # Display legend
# plt.tight_layout()
# plt.show()

# %%
# custom_order = ["Winter", "Spring", "Summer", "Fall"]

# plt.figure(figsize=(6, 6))

# # Plot the bar chart
# sales_df.groupby('Season')['Units Sold'].sum().loc[custom_order].plot(kind='bar', color='skyblue', label='Bar Chart')

# # Plot the frequency polygon
# sales_df.groupby('Season')['Units Sold'].sum().loc[custom_order].plot(kind='line', marker='o', color='orange', linewidth=2, label='Frequency Polygon')

# plt.title('Milk Sales by Time Period')
# plt.xlabel('Time Period')
# plt.ylabel('Units Sold')
# plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
# plt.grid(axis='y', linestyle='--', alpha=0.7)
# plt.legend()  # Display legend
# plt.tight_layout()
# plt.show()

# %%
# import numpy as np
# import matplotlib.pyplot as plt

# # Generate an array of 100,000 random whole numbers between 0 and 1000
# random_numbers = np.random.randint(0, 100, size=1000000000)

# # Plot the histogram to visualize the distribution
# plt.hist(random_numbers, bins=100, edgecolor='black')
# plt.title('Distribution of Random Whole Numbers')
# plt.xlabel('Number')
# plt.ylabel('Frequency')
# plt.show()

# %% [markdown]
# Inventory data
